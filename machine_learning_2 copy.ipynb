# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dados_menos_outliers.csv')
df.head(5)
# Out:
#      id                                              nome  host_id  host_name  \
# 0  2595                             Skylit Midtown Castle     2845   Jennifer
# 1  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
# 2  5022  Entire Apt: Spacious Studio/Loft by central park     7192      Laura
# 3  5099         Large Cozy 1 BR Apartment In Midtown East     7322      Chris
# 4  5203                Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   bairro_group           bairro  latitude  longitude        room_type  price  \
# 0    Manhattan          Midtown  40.75362  -73.98377  Entire home/apt    225
# 1    Manhattan           Harlem  40.80902  -73.94190     Private room    150
# 2    Manhattan      East Harlem  40.79851  -73.94399  Entire home/apt     80
# 3    Manhattan      Murray Hill  40.74767  -73.97500  Entire home/apt    200
# 4    Manhattan  Upper West Side  40.80178  -73.96723     Private room     79
#
# ...

# %%
from pycaret.regression import *

# %%
modelo = df[['minimo_noites',  'disponibilidade_365','price', 'bairro_group', 'room_type']]

# %%
reg_model = setup(data=modelo, target= 'price',  normalize= True, normalize_method='zscore',
                   transformation=True, session_id=980)
# Out:
# <style type="text/css">
# #T_efc24_row9_col1, #T_efc24_row15_col1, #T_efc24_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_efc24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efc24_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_efc24_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efc24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efc24_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_efc24_row0_col1" class="data row0 col1" >980</td>
#     </tr>
#     <tr>
#       <th id="T_efc24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efc24_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_efc24_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
# ...

# %%
melhor_modelo = compare_models(n_select=1)
# Out:
# <style type="text/css">
# #T_43843 th {
#   text-align: left;
# }
# ...

# %%
import pickle

# %%
with open('modelo_machine_learning.pkl', 'wb') as file:
    pickle.dump(melhor_modelo, file)

# %%
amostra = pd.DataFrame({'id': [2595],
                        'nome': ['Skylit Midtown Castle'],
                        'host_id': [2845],
                        'host_name': ['Jennifer'],
                        'bairro_group': ['Manhattan'],
                        'bairro': ['Midtown'], 
                        'latitude': [40.75362], 
                        'longitude': [-73.98377],
                        'room_type': ['Entire home/apt'], 
                        'price': [225], 
                        'minimo_noites': [1],
                        'numero_de_reviews': [45], 
                        'ultima_review': ['2019-05-21'],
                        'reviews_por_mes': [0.38], 
                        'calculado_host_listings_count': [2],
                        'disponibilidade_365': [355]}
                              )

# %%
prediction_melhor = predict_model(melhor_modelo, data = amostra)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a775">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a775_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a775_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5a775_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5a775_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5a775_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5a775_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5a775_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a775_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a775_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5a775_row0_col1" class="data row0 col1" >29.6304</td>
# ...

# %%
print('Preço predito $',prediction_melhor['prediction_label'].values[0].round(2))
# Out:
# Preço predito $ 254.63
